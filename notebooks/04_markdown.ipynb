# %% [markdown]
# # Echelon Project Documentation Demo
#
# This notebook demonstrates how to use Markdown properly in Jupyter Notebook.
# It focuses on headings, lists, inline code, and code blocks.

# %% [markdown]
# ## 1. What is Markdown?
#
# Markdown is a lightweight formatting language used to document analysis inside Jupyter Notebooks.
# It helps explain code, logic, and results clearly.

# %% [markdown]
# ### Why Markdown Matters
#
# - Makes notebooks easy to understand
# - Improves readability
# - Helps reviewers follow logic
# - Documents assumptions clearly
# - Makes projects professional

# %% [markdown]
# ### Steps in Data Science Workflow
#
# 1. Data Collection
# 2. Data Cleaning
# 3. Feature Engineering
# 4. Model Building
# 5. Evaluation
# 6. Interpretation

# %% [markdown]
# ### Example of Inline Code
#
# The library `pandas` is used for data manipulation.
#
# We import it using:
#
# `import pandas as pd`

# %%
### Example of Code Block

import pandas as pd

data = {
    "user_id": [1, 2, 3],
    "role": ["DB_Admin", "HR_Admin", "Cloud_Admin"]
}

df = pd.DataFrame(data)
df.head()
# Out:
#    user_id         role
# 0        1     DB_Admin
# 1        2     HR_Admin
# 2        3  Cloud_Admin

# %% [markdown]
# ### Output Explanation
#
# The output displays a Pandas DataFrame with:
#
# - 3 user IDs
# - Corresponding role assignments
#
# This example demonstrates how Markdown is used to interpret results after executing code, ensuring clarity and readability.
