# %% [markdown]
# # 04 - Statistical Analysis
#
# Objective:
# Perform statistical profiling of engineered features to understand behavioral patterns.
#
# Planned Analysis:
# - Distribution analysis
# - Mean and variance comparison
# - Role-based statistical summaries
# - Z-score computation
# - Outlier detection
